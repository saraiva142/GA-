# %% [markdown]
# <a href="https://colab.research.google.com/github/saraiva142/GA-/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dados o(s) foco(s) e o(s) pontos extremos , construir as curvas (Elipse, parábolas e hipérbole);

# %% [markdown]
# ##**Elipse**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# onde (h,k) é o centro, a é o semi-eixo maior e b é o semi-eixo menor
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
pip install sympy

# %%
import matplotlib.pyplot as plt
import numpy as np
import re

def plot_elipse_from_equation(equation):
    match = re.match(r"(\d+)x\^2 \+ (\d+)y\^2 = (\d+)", equation)
    if not match:
        print("Formato da equação inválido.")
        return

    A, B, C = map(float, match.groups())

    if A <= 0 or B <= 0:
        print("A equação não representa uma elipse válida.")
        return

    h = 0  # O centro (h, k) está no eixo x da forma (x - h)^2, aqui h=0
    k = 0  # O centro (h, k) está no eixo y da forma (y - k)^2, aqui k=0

    a = np.sqrt(C / A)
    b = np.sqrt(C / B)

    if np.isnan(a) or np.isnan(b):
        print("A equação não representa uma elipse válida.")
        return


    c = np.sqrt(abs(a**2 - b**2))
    #Tratando se o eixo maior vai ser no eixo Y ou eixo X
    F1 = (h, k - c) if A > B else (h - c, k)
    F2 = (h, k + c) if A > B else (h + c, k)

    theta = np.linspace(0, 2 * np.pi, 100)
    x = h + a * np.cos(theta)
    y = k + b * np.sin(theta)

    plt.plot(x, y, label='Elipse')
    plt.scatter([F1[0], F2[0]], [F1[1], F2[1]], color='red', label='Focos')
    plt.title(f'Elipse a partir da Equação: {equation}')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.legend()
    plt.grid(True)
    plt.axis('equal')
    plt.show()

    print(f'Coordenadas dos Focos:')
    print(f'Foco 1 (F1): {F1}')
    print(f'Foco 2 (F2): {F2}')
    print(f'Semi-eixo maior (a): {a}')
    print(f'Semi-eixo menor (b): {b}')

equation = "4x^2 + 1y^2 = 16"
plot_elipse_from_equation(equation)
# Out:
# Coordenadas dos Focos:
# Foco 1 (F1): (0, -3.4641016151377544)
# Foco 2 (F2): (0, 3.4641016151377544)
# Semi-eixo maior (a): 2.0
# Semi-eixo menor (b): 4.0

# %% [markdown]
# ##Parábola

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***x^2 = 2py***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Entrada como equação:
# Esse aqui não ficou muito legal não, se possível pular para o de vértice e foco que foquei mais kk

# %%
import matplotlib.pyplot as plt
import numpy as np
import re

def plot_parabola_from_equation(equation):
    match = re.match(r"(\d+)x\^2 \+ (\d+)y = 0", equation)
    if not match:
        print("Formato da equação inválido.")
        return

    A, B = map(float, match.groups())

    if A == 0 or B == 0:
        print("A equação não representa uma parábola válida.")
        return

    # Vértice da parábola (sempre na origem para esta forma de equação)
    h = 0
    k = 0


    x = np.linspace(-10, 10, 1000)
    y = -A * x**2 / B

    plt.plot(x, y, label='Parábola')
    plt.title(f'Parábola a partir da Equação: {equation}')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.legend()
    plt.grid(True)
    plt.show()

    print(f'Vértice da Parábola:')
    print(f'Vertice: ({h}, {k})')

# Exemplo de uso com a equação fornecida
equation = "1x^2 + 4y = 0"
plot_parabola_from_equation(equation)
# Out:
# Vértice da Parábola:
# Vertice: (0, 0)

# %% [markdown]
# * Entrada apenas com focos e vértice

# %%
import numpy as np
import matplotlib.pyplot as plt

def criar_parabola(vertice, foco):
    h, k = vertice
    f, g = foco

    # Determinar a direção da abertura
    if h == f:
        # Parábola abre para cima ou para baixo
        a = 1 if g > k else -1
        direcao = "para cima" if g > k else "para baixo"
        equacao = f"y = {a}(x - {h})^2 + {k}"
        x = np.linspace(h - 5, h + 5, 1000)
        y = a * (x - h)**2 + k
    elif k == g:
        # Parábola abre para a direita ou para a esquerda
        a = 1 if f > h else -1
        direcao = "para a direita" if f > h else "para a esquerda"
        equacao = f"y = {a}(x - {h})^2 + {k}"
        y = np.linspace(k - 5, k + 5, 1000)
        x = a * (y - k)**2 + h
    else:
        raise ValueError("Vértice e foco não definem uma parábola válida.")

    print(f"A parábola {equacao} abre {direcao}.")


    # Plotar a parábola
    plt.plot(x, y, label=equacao)
    plt.scatter([h, f], [k, g], color='red')  # Marcando vértice e foco
    plt.title('Parábola')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.axhline(0, color='black',linewidth=0.5)
    plt.axvline(0, color='black',linewidth=0.5)
    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.legend()
    plt.show()

# Exemplo de uso:
vertice = (5, 4)
foco = (8, 4)
criar_parabola(vertice, foco)
# Out:
# A parábola y = 1(x - 5)^2 + 4 abre para a direita.

# %% [markdown]
# ##Hipérbole

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

def criar_hiperbole(A1, A2, foco):
    x1, y1 = A1
    x2, y2 = A2
    fx, fy = foco

    # Calcular o centro da hipérbole
    h = (x1 + x2) / 2
    k = (y1 + y2) / 2

    # Calcular distâncias do centro aos vértices e ao foco
    a = np.sqrt((x1 - h)**2 + (y1 - k)**2)
    b = np.sqrt((x2 - h)**2 + (y2 - k)**2)
    c = np.sqrt((fx - h)**2 + (fy - k)**2)



    # Parâmetro da hipérbole
    e = c / a

    # Determinar a direção dos eixos
    if x1 == x2 and x1 == fx and x2 == fx:
            # Eixo vertical
            a = abs(fx - h)
            b = abs(fy - k)
            direcao = "vertical"
            equacao = f"((x - {h})**2) / ({a}**2) - ((y - {k})**2) / ({b}**2) = 1"
            y = np.linspace(k - 5, k + 5, 1000)
            x_positive = h + a * np.sqrt(1 + ((y - k) / b)**2)
            x_negative = h - a * np.sqrt(1 + ((y - k) / b)**2)
            plt.plot(x_positive, y, label='Hipérbole')
            plt.plot(x_negative, y)
            fx2 = h  # Manter fx2 igual a h, pois a direção é vertical
            fy2 = k - b
    elif y1 == y2 and y1 == fy and y2 == fy:
            # Eixo horizontal
            a = abs(fx - h)
            b = abs(fy - k)
            direcao = "horizontal"
            equacao = f"((x - {h})**2) / ({a}**2) - ((y - {k})**2) / ({b}**2) = 1"
            x = np.linspace(h - 5, h + 5, 1000)
            y_positive = k + b * np.sqrt(1 - ((x - h) / a)**2)  # Ajuste para o sinal correto
            y_negative = k - b * np.sqrt(1 - ((x - h) / a)**2)  # Ajuste para o sinal correto
            plt.plot(x, y_positive, label='Hipérbole')
            plt.plot(x, y_negative)
            fx2 = h - a
            fy2 = k  # Manter fy2 igual a k, pois a direção é horizontal

    # Plotar a hipérbole
    # if x1 == x2 and x1 == fx and x2 == fx:
    #     plt.plot(x_positive, y, label='Hipérbole')
    #     plt.plot(x_negative, y)
    # elif y1 == y2 and y1 == fy and y2 == fy:
    #     plt.plot(x, y_positive, label='Hipérbole')
    #     plt.plot(x, y_negative)

    # Plotar o centro e os focos
    plt.scatter(h, k, color='green', label='Centro')
    plt.scatter([fx, fx2], [fy, fy2], color='purple', label='Focos')

    # Marcando vértices
    plt.scatter([x1, x2], [y1, y2], color='red')

    plt.title(f'Hipérbole - Direção {direcao}')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Exemplo de uso:
A1 = (1, -2)
A2 = (5, -2)
foco = (6, -2)
criar_hiperbole(A1, A2, foco)
# Out:
# <ipython-input-54-4b5e96601f78>:44: RuntimeWarning: invalid value encountered in sqrt
#   y_positive = k + b * np.sqrt(1 - ((x - h) / a)**2)  # Ajuste para o sinal correto
# <ipython-input-54-4b5e96601f78>:45: RuntimeWarning: invalid value encountered in sqrt
#   y_negative = k - b * np.sqrt(1 - ((x - h) / a)**2)  # Ajuste para o sinal correto

# %%
import numpy as np
import matplotlib.pyplot as plt

def criar_h(vertice1, vertice2, foco):
    x1, y1 = vertice1
    x2, y2 = vertice2
    fx, fy = foco

    # Calcular o centro da hipérbole
    h = (x1 + x2) / 2
    k = (y1 + y2) / 2

    # Calcular distâncias do centro aos vértices e ao foco
    a = np.sqrt((x1 - h)**2 + (y1 - k)**2)
    b = np.sqrt((x2 - h)**2 + (y2 - k)**2)
    c = np.sqrt((fx - h)**2 + (fy - k)**2)

    # Parâmetro da hipérbole
    e = c / a

    # Determinar a direção da abertura
    if x1 == x2:
        # A hipérbole abre para a esquerda ou para a direita
        x = np.linspace(h - a - 1, h + a + 1, 400)
        y_pos = k + b * np.sqrt(1 + ((x - h)**2 / a**2))
        y_neg = k - b * np.sqrt(1 + ((x - h)**2 / a**2))
        plt.plot(x, y_pos, label=f"Hipérbole: e={e}")
        plt.plot(x, y_neg, color='blue')
    elif y1 == y2:
        # A hipérbole abre para cima ou para baixo
        y = np.linspace(k - b - 1, k + b + 1, 400)
        x_pos = h + a * np.sqrt(1 + ((y - k)**2 / b**2))
        x_neg = h - a * np.sqrt(1 + ((y - k)**2 / b**2))
        plt.plot(x_pos, y, label=f"Hipérbole: e={e}")
        plt.plot(x_neg, y, color='blue')
    else:
        raise ValueError("Vértice e foco não definem uma hipérbole válida.")

    print(f"A hipérbole é definida pelos pontos dados.")
    print(f"Centro da hipérbole: ({h}, {k})")
    print(f"Outro foco da hipérbole: ({2 * h - fx}, {2 * k - fy})")

    # Marcando vértice, foco, centro e outro foco
    plt.scatter([x1, x2, fx, h, 2 * h - fx], [y1, y2, fy, k, 2 * k - fy], color='red')
    plt.title('Hipérbole')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Pontos
A1 = (1, -2)
A2 = (5, -2)
foco = (6, -2)

# Chamando a função
criar_h(A1, A2, foco)
# Out:
# A hipérbole é definida pelos pontos dados.
# Centro da hipérbole: (3.0, -2.0)
# Outro foco da hipérbole: (0.0, -2.0)
